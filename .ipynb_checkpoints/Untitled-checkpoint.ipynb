# %% [markdown]
# # Xente Fraud Detection Challenge

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as mpl
import matplotlib.pyplot as plt
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTENC

# %% [markdown]
# ## Import the Datasets

# %%
df_train = pd.read_csv("training.csv")
df_test = pd.read_csv("test.csv")

# %% [markdown]
# ## Basic analysis on the Datasets

# %%
df_train.head(15)
# Out:
#            TransactionId         BatchId       AccountId       SubscriptionId  \
# 0    TransactionId_76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1    TransactionId_73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2    TransactionId_26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3      TransactionId_380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4    TransactionId_28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
# 5    TransactionId_23223   BatchId_25954  AccountId_1078  SubscriptionId_4238
# 6   TransactionId_118063  BatchId_118460  AccountId_2442  SubscriptionId_1980
# 7   TransactionId_100640   BatchId_38561  AccountId_4841  SubscriptionId_3829
# 8    TransactionId_51905   BatchId_93774   AccountId_272  SubscriptionId_4731
# 9   TransactionId_130161   BatchId_82409   AccountId_710   SubscriptionId_920
# 10   TransactionId_51800  BatchId_112288  AccountId_2634  SubscriptionId_3511
# 11   TransactionId_33857  BatchId_126394  AccountId_4841  SubscriptionId_3829
# 12   TransactionId_94963  BatchId_104726   AccountId_710   SubscriptionId_920
# 13  TransactionId_104687   BatchId_59433   AccountId_710   SubscriptionId_920
# 14   TransactionId_86903   BatchId_59433   AccountId_710   SubscriptionId_920
#
#          CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0   CustomerId_4406          UGX          256  ProviderId_6  ProductId_10
# 1   CustomerId_4406          UGX          256  ProviderId_4   ProductId_6
# 2   CustomerId_4683          UGX          256  ProviderId_6   ProductId_1
# 3    CustomerId_988          UGX          256  ProviderId_1  ProductId_21
# 4    CustomerId_988          UGX          256  ProviderId_4   ProductId_6
# 5   CustomerId_1432          UGX          256  ProviderId_6   ProductId_3
# 6   CustomerId_2858          UGX          256  ProviderId_5   ProductId_3
# 7   CustomerId_2858          UGX          256  ProviderId_4   ProductId_6
# 8    CustomerId_598          UGX          256  ProviderId_6  ProductId_10
# 9   CustomerId_1053          UGX          256  ProviderId_1  ProductId_15
# 10  CustomerId_3052          UGX          256  ProviderId_6   ProductId_3
# 11  CustomerId_3052          UGX          256  ProviderId_4   ProductId_6
# 12  CustomerId_1053          UGX          256  ProviderId_1  ProductId_15
# 13  CustomerId_1053          UGX          256  ProviderId_3  ProductId_15
# 14  CustomerId_1053          UGX          256  ProviderId_3  ProductId_15
#
#        ProductCategory    ChannelId   Amount  Value  TransactionStartTime  \
# 0              airtime  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z
# 1   financial_services  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z
# 2              airtime  ChannelId_3    500.0    500  2018-11-15T02:44:21Z
# 3         utility_bill  ChannelId_3  20000.0  21800  2018-11-15T03:32:55Z
# 4   financial_services  ChannelId_2   -644.0    644  2018-11-15T03:34:21Z
# 5              airtime  ChannelId_3   2000.0   2000  2018-11-15T03:35:10Z
# 6              airtime  ChannelId_3  10000.0  10000  2018-11-15T03:44:31Z
# 7   financial_services  ChannelId_2   -500.0    500  2018-11-15T03:45:13Z
# 8              airtime  ChannelId_3    500.0    500  2018-11-15T04:14:59Z
# 9   financial_services  ChannelId_3    600.0    600  2018-11-15T04:31:48Z
# 10             airtime  ChannelId_3    890.0    890  2018-11-15T04:32:08Z
# 11  financial_services  ChannelId_2    -40.0     40  2018-11-15T04:32:42Z
# 12  financial_services  ChannelId_3    600.0    600  2018-11-15T04:35:10Z
# 13  financial_services  ChannelId_3   4000.0   4000  2018-11-15T04:47:31Z
# 14  financial_services  ChannelId_3   4000.0   4000  2018-11-15T04:48:09Z
#
#     PricingStrategy  FraudResult
# 0                 2            0
# 1                 2            0
# 2                 2            0
# 3                 2            0
# 4                 2            0
# 5                 2            0
# 6                 4            0
# 7                 2            0
# 8                 2            0
# 9                 2            0
# 10                2            0
# 11                2            0
# 12                2            0
# 13                2            0
# 14                2            0

# %%
df_train.shape
# Out:
# (95662, 16)

# %%
df_test.head(10)
# Out:
#           TransactionId         BatchId       AccountId       SubscriptionId  \
# 0   TransactionId_50600   BatchId_35028  AccountId_2441  SubscriptionId_4426
# 1   TransactionId_95109   BatchId_45139  AccountId_3439  SubscriptionId_2643
# 2   TransactionId_47357   BatchId_74887  AccountId_4841  SubscriptionId_3829
# 3   TransactionId_28185   BatchId_11025  AccountId_2685  SubscriptionId_4626
# 4   TransactionId_22140   BatchId_29804  AccountId_4841  SubscriptionId_3829
# 5  TransactionId_134338   BatchId_67575  AccountId_3439  SubscriptionId_2643
# 6  TransactionId_109096   BatchId_52375  AccountId_4841  SubscriptionId_3829
# 7   TransactionId_14249  BatchId_112552  AccountId_2908  SubscriptionId_2977
# 8   TransactionId_69896   BatchId_60867  AccountId_4841  SubscriptionId_3829
# 9   TransactionId_91468   BatchId_14721   AccountId_460  SubscriptionId_2976
#
#         CustomerId CurrencyCode  CountryCode    ProviderId     ProductId  \
# 0  CustomerId_2857          UGX          256  ProviderId_5   ProductId_3
# 1  CustomerId_3874          UGX          256  ProviderId_5  ProductId_15
# 2  CustomerId_2857          UGX          256  ProviderId_4   ProductId_6
# 3  CustomerId_3105          UGX          256  ProviderId_5  ProductId_10
# 4  CustomerId_3105          UGX          256  ProviderId_4   ProductId_6
# 5  CustomerId_3874          UGX          256  ProviderId_6   ProductId_3
# 6  CustomerId_3874          UGX          256  ProviderId_4   ProductId_6
# 7  CustomerId_3332          UGX          256  ProviderId_3   ProductId_3
# 8  CustomerId_3332          UGX          256  ProviderId_4   ProductId_6
# 9   CustomerId_790          UGX          256  ProviderId_3  ProductId_14
#
#       ProductCategory    ChannelId  Amount  Value  TransactionStartTime  \
# 0             airtime  ChannelId_3  1000.0   1000  2019-02-13T10:01:40Z
# 1  financial_services  ChannelId_3  2000.0   2000  2019-02-13T10:02:12Z
# 2  financial_services  ChannelId_2   -50.0     50  2019-02-13T10:02:30Z
# 3             airtime  ChannelId_3  3000.0   3000  2019-02-13T10:02:38Z
# 4  financial_services  ChannelId_2   -60.0     60  2019-02-13T10:02:58Z
# 5             airtime  ChannelId_3  1000.0   1000  2019-02-13T10:03:12Z
# 6  financial_services  ChannelId_2   -50.0     50  2019-02-13T10:03:48Z
# 7             airtime  ChannelId_3  1000.0   1000  2019-02-13T10:09:46Z
# 8  financial_services  ChannelId_2   -50.0     50  2019-02-13T10:11:24Z
# 9  financial_services  ChannelId_3  1161.0   1161  2019-02-13T10:12:08Z
#
#    PricingStrategy
# 0                4
# 1                2
# 2                2
# 3                4
# 4                2
# 5                2
# 6                2
# 7                1
# 8                2
# 9                0

# %%
df_test.shape
# Out:
# (45019, 15)

# %%
print("Non-fraudulent samples: {}".format(len(df_train[df_train["FraudResult"] == 0])))
print("Fraudulent samples: {}".format(len(df_train[df_train["FraudResult"] == 1])))
plt.hist(df_train["FraudResult"])
plt.show()
# Out:
# Non-fraudulent samples: 95469
# Fraudulent samples: 193

# %% [markdown]
# The dataset is heavily inbalanced, with only 0.2% of the samples being fraudulent.

# %% [markdown]
# ## Data Preprocessing

# %%
df_train.describe(include="all")
# Out:
#               TransactionId        BatchId       AccountId  \
# count                 95662          95662           95662
# unique                95662          94809            3633
# top     TransactionId_76871  BatchId_67019  AccountId_4841
# freq                      1             28           30893
# mean                    NaN            NaN             NaN
# std                     NaN            NaN             NaN
# min                     NaN            NaN             NaN
# 25%                     NaN            NaN             NaN
# 50%                     NaN            NaN             NaN
# 75%                     NaN            NaN             NaN
# max                     NaN            NaN             NaN
#
#              SubscriptionId       CustomerId CurrencyCode  CountryCode  \
# count                 95662            95662        95662      95662.0
# unique                 3627             3742            1          NaN
# top     SubscriptionId_3829  CustomerId_7343          UGX          NaN
# freq                  32630             4091        95662          NaN
# mean                    NaN              NaN          NaN        256.0
# std                     NaN              NaN          NaN          0.0
# min                     NaN              NaN          NaN        256.0
# 25%                     NaN              NaN          NaN        256.0
# 50%                     NaN              NaN          NaN        256.0
# 75%                     NaN              NaN          NaN        256.0
# max                     NaN              NaN          NaN        256.0
#
#           ProviderId    ProductId     ProductCategory    ChannelId  \
# count          95662        95662               95662        95662
# unique             6           23                   9            4
# top     ProviderId_4  ProductId_6  financial_services  ChannelId_3
# freq           38189        32635               45405        56935
# mean             NaN          NaN                 NaN          NaN
# std              NaN          NaN                 NaN          NaN
# min              NaN          NaN                 NaN          NaN
# 25%              NaN          NaN                 NaN          NaN
# 50%              NaN          NaN                 NaN          NaN
# 75%              NaN          NaN                 NaN          NaN
# max              NaN          NaN                 NaN          NaN
#
#               Amount         Value  TransactionStartTime  PricingStrategy  \
# count   9.566200e+04  9.566200e+04                 95662     95662.000000
# unique           NaN           NaN                 94556              NaN
# top              NaN           NaN  2018-12-24T16:30:13Z              NaN
# freq             NaN           NaN                    17              NaN
# mean    6.717846e+03  9.900584e+03                   NaN         2.255974
# std     1.233068e+05  1.231221e+05                   NaN         0.732924
# min    -1.000000e+06  2.000000e+00                   NaN         0.000000
# 25%    -5.000000e+01  2.750000e+02                   NaN         2.000000
# 50%     1.000000e+03  1.000000e+03                   NaN         2.000000
# 75%     2.800000e+03  5.000000e+03                   NaN         2.000000
# max     9.880000e+06  9.880000e+06                   NaN         4.000000
#
#          FraudResult
# count   95662.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean        0.002018
# std         0.044872
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df_train.CurrencyCode.unique()
# Out:
# array(['UGX'], dtype=object)

# %%
df_train.CountryCode.unique()
# Out:
# array([256], dtype=int64)

# %% [markdown]
# We notice that the variables CurrencyCode and CountryCode have only 1 value and can therefore be removed since they don't bring any relevant information. We also remove these variables from the test set.

# %%
df_train = df_train.drop(columns=['CurrencyCode', 'CountryCode'], axis=1)
df_test = df_test.drop(columns=['CurrencyCode', 'CountryCode'], axis=1)

# %% [markdown]
# We also can notice that all the columns that refer to id are in the following form: " nameOfTheColumn_Id ".
# For example:

# %%
identifiers = df_train.loc[:, ['TransactionId', 'BatchId', 'AccountId', 'SubscriptionId', 'CustomerId', 'ProviderId', 'ProductId', 'ChannelId']]
identifiers
# Out:
#               TransactionId         BatchId       AccountId  \
# 0       TransactionId_76871   BatchId_36123  AccountId_3957
# 1       TransactionId_73770   BatchId_15642  AccountId_4841
# 2       TransactionId_26203   BatchId_53941  AccountId_4229
# 3         TransactionId_380  BatchId_102363   AccountId_648
# 4       TransactionId_28195   BatchId_38780  AccountId_4841
# ...                     ...             ...             ...
# 95657   TransactionId_89881   BatchId_96668  AccountId_4841
# 95658   TransactionId_91597    BatchId_3503  AccountId_3439
# 95659   TransactionId_82501  BatchId_118602  AccountId_4841
# 95660  TransactionId_136354   BatchId_70924  AccountId_1346
# 95661   TransactionId_35670   BatchId_29317  AccountId_4841
#
#             SubscriptionId       CustomerId    ProviderId     ProductId  \
# 0       SubscriptionId_887  CustomerId_4406  ProviderId_6  ProductId_10
# 1      SubscriptionId_3829  CustomerId_4406  ProviderId_4   ProductId_6
# 2       SubscriptionId_222  CustomerId_4683  ProviderId_6   ProductId_1
# 3      SubscriptionId_2185   CustomerId_988  ProviderId_1  ProductId_21
# 4      SubscriptionId_3829   CustomerId_988  ProviderId_4   ProductId_6
# ...                    ...              ...           ...           ...
# 95657  SubscriptionId_3829  CustomerId_3078  ProviderId_4   ProductId_6
# 95658  SubscriptionId_2643  CustomerId_3874  ProviderId_6  ProductId_10
# 95659  SubscriptionId_3829  CustomerId_3874  ProviderId_4   ProductId_6
# 95660   SubscriptionId_652  CustomerId_1709  ProviderId_6  ProductId_19
# 95661  SubscriptionId_3829  CustomerId_1709  ProviderId_4   ProductId_6
#
#          ChannelId
# 0      ChannelId_3
# 1      ChannelId_2
# 2      ChannelId_3
# 3      ChannelId_3
# 4      ChannelId_2
# ...            ...
# 95657  ChannelId_2
# 95658  ChannelId_3
# 95659  ChannelId_2
# 95660  ChannelId_3
# 95661  ChannelId_2
#
# [95662 rows x 8 columns]

# %% [markdown]
# Therefore we can remove all the irrelevent strings from these columns.

# %%
df_train['TransactionId'] = df_train['TransactionId'].str.replace(r'\D', '').astype(int)
df_train['BatchId'] = df_train['BatchId'].str.replace(r'\D', '').astype(int)
df_train['AccountId'] = df_train['AccountId'].str.replace(r'\D', '').astype(int)
df_train['SubscriptionId'] = df_train['SubscriptionId'].str.replace(r'\D', '').astype(int)
df_train['CustomerId'] = df_train['CustomerId'].str.replace(r'\D', '').astype(int)
df_train['ProviderId'] = df_train['ProviderId'].str.replace(r'\D', '').astype(int)
df_train['ProductId'] = df_train['ProductId'].str.replace(r'\D', '').astype(int)
df_train['ChannelId'] = df_train['ChannelId'].str.replace(r'\D', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10828/438449030.py in <module>
# ----> 1 df_train['TransactionId'] = df_train['TransactionId'].str.replace(r'\D', '').astype(int)
#       2 df_train['BatchId'] = df_train['BatchId'].str.replace(r'\D', '').astype(int)
#       3 df_train['AccountId'] = df_train['AccountId'].str.replace(r'\D', '').astype(int)
#       4 df_train['SubscriptionId'] = df_train['SubscriptionId'].str.replace(r'\D', '').astype(int)
#       5 df_train['CustomerId'] = df_train['CustomerId'].str.replace(r'\D', '').astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
df_train.head()
# Out:
#    TransactionId         BatchId       AccountId       SubscriptionId  \
# 0          76871   BatchId_36123  AccountId_3957   SubscriptionId_887
# 1          73770   BatchId_15642  AccountId_4841  SubscriptionId_3829
# 2          26203   BatchId_53941  AccountId_4229   SubscriptionId_222
# 3            380  BatchId_102363   AccountId_648  SubscriptionId_2185
# 4          28195   BatchId_38780  AccountId_4841  SubscriptionId_3829
#
#         CustomerId    ProviderId     ProductId     ProductCategory  \
# 0  CustomerId_4406  ProviderId_6  ProductId_10             airtime
# 1  CustomerId_4406  ProviderId_4   ProductId_6  financial_services
# 2  CustomerId_4683  ProviderId_6   ProductId_1             airtime
# 3   CustomerId_988  ProviderId_1  ProductId_21        utility_bill
# 4   CustomerId_988  ProviderId_4   ProductId_6  financial_services
#
#      ChannelId   Amount  Value  TransactionStartTime  PricingStrategy  \
# 0  ChannelId_3   1000.0   1000  2018-11-15T02:18:49Z                2
# 1  ChannelId_2    -20.0     20  2018-11-15T02:19:08Z                2
# 2  ChannelId_3    500.0    500  2018-11-15T02:44:21Z                2
# 3  ChannelId_3  20000.0  21800  2018-11-15T03:32:55Z                2
# 4  ChannelId_2   -644.0    644  2018-11-15T03:34:21Z                2
#
#    FraudResult
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df_train.dtypes
# Out:
# TransactionId            object
# BatchId                  object
# AccountId                object
# SubscriptionId           object
# CustomerId               object
# ProviderId               object
# ProductId                object
# ProductCategory          object
# ChannelId                object
# Amount                  float64
# Value                     int64
# TransactionStartTime     object
# PricingStrategy           int64
# FraudResult               int64
# dtype: object

# %% [markdown]
# We see that the TransactionStartTime is of type "object" whereas it could be considered as a date. We therefore modify the strings describing the date and considere convert this column to a datetime type. We do the same on the test set.
